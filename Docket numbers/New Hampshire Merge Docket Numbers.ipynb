# %%
import pandas as pd
import numpy as np
import os

# %%
#importing docket numbers
docket = pd.read_csv('/Users/samk/Downloads/get_docket_number_21419_2.csv')
docket
# Out:
#              DocketNumber1 DocketNumber2    DocketNumber3  \
# 0            . RG08-418186           NaN    . RG08-418186
# 1                        ?           NaN                ?
# 2            0:13-CV-02820           NaN    0:13-CV-02820
# 3     0:14-cv-04852-RHK-BR           NaN              NaN
# 4                    00-00           NaN            00-00
# 5             00-1-3368-10           NaN              NaN
# 6       00-1-3368-10 (pwb)           NaN              NaN
# 7       00-1-3368-10 (pwb)           NaN              NaN
# 8       00-1-3368-10 (pwb)           NaN              NaN
# 9       00-1-3368-10 (pwb)           NaN              NaN
# 10                00-11338           NaN              NaN
# 11              00-1823-CZ           NaN              NaN
# 12              00-2201JKF           NaN              NaN
# 13              00-2201JKF           NaN              NaN
# 14              00-2201JKF           NaN              NaN
# ...

# %%
#Subsetting the Docket DataFrame
docket_sub = docket.loc[:,['DocketNumber1','trg_LOBDescription','trg_PolicyProductCD','trg_PolicySubProductDesc',
                    'trg_PolicyProductDescription','MatterCourtDistrictName','ClosedOutcomeDesc']]
# Out:
#              DocketNumber1               trg_LOBDescription  \
# 0            . RG08-418186  Products liability - occurrence
# 1                        ?     Other liability - occurrence
# 2            0:13-CV-02820     Other liability - occurrence
# 3     0:14-cv-04852-RHK-BR     Other liability - occurrence
# 4                    00-00     Other liability - occurrence
# 5             00-1-3368-10             Other commercial aut
# 6       00-1-3368-10 (pwb)             Private passenger au
# 7       00-1-3368-10 (pwb)             Other commercial aut
# 8       00-1-3368-10 (pwb)             Commercial auto no-f
# 9       00-1-3368-10 (pwb)             Other commercial aut
# 10                00-11338             Other liability - oc
# 11              00-1823-CZ             Other liability - oc
# 12              00-2201JKF     Other liability - occurrence
# 13              00-2201JKF             Products liability -
# 14              00-2201JKF  Products liability - occurrence
# ...

# %%
#Subsetting New Hampshire cases
docket_nh = docket_sub.loc[docket_sub['MatterCourtDistrictName'] == 'New Hampshire']
docket_nh
# Out:
#          DocketNumber1               trg_LOBDescription trg_PolicyProductCD  \
# 0        . RG08-418186  Products liability - occurrence                  GL
# 1                    ?     Other liability - occurrence                  GL
# 2        0:13-CV-02820     Other liability - occurrence                  GL
# 4                00-00     Other liability - occurrence                  GL
# 30                   0     Other liability - occurrence                  GL
# 31                   0  Products liability - occurrence                  GL
# 32                   0     Other liability - occurrence                  GL
# 33                   0     Other liability - occurrence                  GL
# 34                  10     Other liability - occurrence                  GL
# 36                 139     Other liability - occurrence                  GL
# 37         000200-2009     Other liability - occurrence                  GL
# ...

# %%
len(docket_nh)
# Out:
# 6911

# %%
#importing New Hampshire data
nh = pd.read_csv('/Users/samk/Documents/GitHub/UNH_MS_Work/data/processed/New_Hampshire.csv')

# %%
#Exploring docket number formats
nh_cases = nh.dropna(subset = ['docket_number'])
nh_cases['docket_number'] = nh_cases['docket_number'].apply(lambda x: x.strip('No.'))
nh_cases['docket_number'] = nh_cases['docket_number'].apply(lambda x: x.strip('-'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
len(nh_cases)
# Out:
# 10409

# %%
nh_cases
# Out:
#        citation_num citation_type  court_id                   court_name  \
# 0      144 N.H. 131      official      8797  New Hampshire Supreme Court
# 1       144 N.H. 13      official      8797  New Hampshire Supreme Court
# 2      144 N.H. 138      official      8797  New Hampshire Supreme Court
# 3      144 N.H. 107      official      8797  New Hampshire Supreme Court
# 4       144 N.H. 44      official      8797  New Hampshire Supreme Court
# 5      144 N.H. 198      official      8797  New Hampshire Supreme Court
# 6      144 N.H. 175      official      8797  New Hampshire Supreme Court
# 7      144 N.H. 249      official      8797  New Hampshire Supreme Court
# 8      144 N.H. 467      official      8797  New Hampshire Supreme Court
# 9      144 N.H. 336      official      8797  New Hampshire Supreme Court
# 10     144 N.H. 607      official      8797  New Hampshire Supreme Court
# 11      144 N.H. 27      official      8797  New Hampshire Supreme Court
# ...
